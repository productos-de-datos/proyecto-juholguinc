# %%
import xlrd
import csv
import pandas as pd

# %%
import urllib.request

url = 'https://github.com/jdvelasq/datalabs/raw/master/datasets/precio_bolsa_nacional/xls/2017.xls'
file_ = '2017.xlsx'
urllib.request.urlretrieve(url, file_)
# Out:
# ('2017.xlsx', <http.client.HTTPMessage at 0x7fd13b943400>)

# %%
#1995 to 1999
df = pd.read_excel("data_lake/landing/1995.xlsx",  skiprows = range(1, 3), header=1)
df
# Out:
#           Fecha       0       1       2       3       4       5       6  \
# 0    1995-07-20     NaN   1.073   1.073   1.073   1.073   1.073   1.073
# 1    1995-07-21   1.073   1.000   1.000   1.000   1.000   1.000   5.000
# 2    1995-07-22   1.073   1.073   1.000   1.000   1.000   1.073   1.303
# 3    1995-07-23   1.073   1.000   1.000   1.000   1.000   1.000   0.100
# 4    1995-07-24   1.000   1.000   0.990   1.000   1.000   1.073   3.000
# ..          ...     ...     ...     ...     ...     ...     ...     ...
# 160  1995-12-27  15.000  15.000  15.000  15.000  15.000  15.000  15.000
# 161  1995-12-28  14.900  14.900  14.900  14.900  14.900  15.000  25.000
# 162  1995-12-29  11.990  11.990  11.990  11.990  15.000  15.243  13.600
# 163  1995-12-30  13.500  12.000  12.000  12.000   9.700  13.500  14.300
# 164  1995-12-31  15.000  14.990  14.990  14.990  14.990  14.990  14.990
#
#           7       8  ...      14      15      16      17      18      19  \
# ...

# %%
#2000 - 2010
# version column 2000 2005 20010
df = pd.read_excel("data_lake/landing/2010.xlsx",  skiprows = range(1, 2), header=1)
df
# Out:
#           Fecha           0           1           2           3           4  \
# 0    2010-01-01  124.687267  124.687267  124.280267  124.687267  124.687267
# 1    2010-01-02  114.503340  112.503340  112.503340  112.503340  112.503340
# 2    2010-01-03  112.790267  112.790267  112.790267  112.687267  112.687267
# 3    2010-01-04  112.587267  112.541267  112.541267  112.587267  112.587267
# 4    2010-01-05  113.587267  113.587267  113.587267  113.587267  113.587267
# ..          ...         ...         ...         ...         ...         ...
# 360  2010-12-27   36.091601   36.091601   34.980601   34.980601   36.091601
# 361  2010-12-28   36.269513   36.269513   36.268513   36.268513   36.269513
# 362  2010-12-29   36.522102   36.522102   36.522102   36.522102   36.522102
# 363  2010-12-30   36.620830   36.619830   35.508830   35.508830   36.619830
# 364  2010-12-31   37.316671   37.316671   37.316671   37.315671   37.316671
#
# ...

# %%
#2011
# version column 
df = pd.read_excel("data_lake/landing/2011.xlsx",  skiprows = range(1, 2), header=1, usecols = "A:Z")
df
# Out:
#           Fecha          0          1          2          3          4  \
# 0    2011-01-01  88.106093  86.106093  65.106093  65.106093  52.106093
# 1    2011-01-02  36.224485  36.224485  36.223485  36.223485  36.223485
# 2    2011-01-03  58.104362  58.104362  58.104362  58.104362  58.104362
# 3    2011-01-04  49.727173  49.727173  49.727173  49.727173  49.727173
# 4    2011-01-05  34.337129  34.337129  34.337129  34.337129  34.337129
# ..          ...        ...        ...        ...        ...        ...
# 364  2011-12-31  39.665407  39.665407  39.664407  39.665407  39.664407
# 365         NaN        NaN        NaN        NaN        NaN        NaN
# 366         NaN        NaN        NaN        NaN        NaN        NaN
# 367         NaN        NaN        NaN        NaN        NaN        NaN
# 368         NaN        NaN        NaN        NaN        NaN        NaN
#
#              5          6          7          8  ...         15         16  \
# ...

# %%
#2011 - 2015
# 2011 to 2014 extra field (average)
df = pd.read_excel("data_lake/landing/2015.xlsx",  skiprows = range(1, 2), header=1)
df
# Out:
#           Fecha           0           1           2           3           4  \
# 0    2015-01-01  184.210107  178.210107  178.210107  178.210107  178.210107
# 1    2015-01-02  149.480854  113.981854   84.480854  113.981854  113.981854
# 2    2015-01-03  198.869354  198.744354  198.869354  190.869354  190.869354
# 3    2015-01-04  242.913838  242.913838  242.913838  242.913838  242.913838
# 4    2015-01-05  189.260771  143.603771  143.603771  143.603771  143.603771
# ..          ...         ...         ...         ...         ...         ...
# 360  2015-12-27  491.437817  491.437817  491.437817  486.437817  486.437817
# 361  2015-12-28  350.168085  350.168085  350.168085  350.168085  350.168085
# 362  2015-12-29  391.159782  325.453782  325.453782  325.453782  325.453782
# 363  2015-12-30  476.726154  446.726154  446.726154  446.726154  446.726154
# 364  2015-12-31  386.629179  376.629179  376.629179  376.629179  376.629179
#
# ...

# %%
# 2016 - 2017 xls
df = pd.read_excel("data_lake/landing/2017.xls",  skiprows = range(1, 2), header=1)
df
# Out:
#           Fecha           0           1           2           3           4  \
# 0    2017-01-01   88.086212   88.086212   88.086212   79.086212   79.086212
# 1    2017-01-02   69.268993   94.268993   69.268993   69.268993   69.268993
# 2    2017-01-03   69.472946   69.472946   69.472946   69.472946   69.472946
# 3    2017-01-04   61.376720   61.376720   61.376720   69.299720   61.376720
# 4    2017-01-05   65.442361   65.442361   65.442361   65.442361   65.442361
# ..          ...         ...         ...         ...         ...         ...
# 360  2017-12-27  140.616930  133.316930  133.316930  133.316930  140.116930
# 361  2017-12-28  133.468686  133.468686  133.468686  133.468686  133.468686
# 362  2017-12-29  124.216608  124.216608  131.216608  114.928608  124.216608
# 363  2017-12-30  163.364148  145.364148  145.364148  140.864148  140.864148
# 364  2017-12-31  150.364909  150.364909  150.364909  135.364909  135.364909
#
# ...

# %%
df = pd.read_excel("data_lake/landing/2021.xlsx")
df
# Out:
#           Fecha       0       1       2       3       4       5       6  \
# 0    2021-01-01  142.31  142.31  142.31  142.31  142.31  142.31  128.31
# 1    2021-01-02   86.12   85.27   86.12   86.12   86.12   86.12   86.11
# 2    2021-01-03  128.16  128.16  128.16  128.16  128.16  128.16  100.16
# 3    2021-01-04  126.46  126.46  126.46  126.46  126.46  134.17  126.46
# 4    2021-01-05  146.45  146.45  146.45  146.45  146.45  146.45  146.45
# ..          ...     ...     ...     ...     ...     ...     ...     ...
# 115  2021-04-26  145.89  163.89  162.74  145.89  163.89  166.50  170.89
# 116  2021-04-27  170.02  170.52  170.02  170.02  170.02  170.52  172.52
# 117  2021-04-28  147.25  147.25  147.25  147.25  147.25  159.23  169.25
# 118  2021-04-29  116.12  129.12  129.12  129.12  129.12  129.12  129.12
# 119  2021-04-30  113.42  113.42  113.42  113.42  113.42  125.42  125.42
#
#           7       8  ...      14      15      16      17      18      19  \
# ...

# %%
pd.pivot_table(data=df,index=['Fecha','0','1'])
# Out:
#                               10      11      12      13      14      15  \
# Fecha      0      1
# 1995-07-21 1.073  1.000    6.000   9.256   9.256   5.000   5.000   1.000
# 1995-07-22 1.073  1.073    1.303   1.303   1.303   1.303   1.073   1.000
# 1995-07-23 1.073  1.000    1.000   1.000   1.238   1.238   1.000   0.100
# 1995-07-24 1.000  1.000    8.845   9.256   3.000   1.073   1.073   1.073
# 1995-07-25 0.990  0.990    1.263   1.263   1.263   1.073   1.073   1.073
# ...                          ...     ...     ...     ...     ...     ...
# 1995-12-27 15.000 15.000  15.000  15.000  15.000  15.000  15.000  15.000
# 1995-12-28 14.900 14.900  30.000  30.000  25.000  25.000  25.000  25.000
# 1995-12-29 11.990 11.990  30.000  30.000  30.000  30.000  30.000  20.000
# 1995-12-30 13.500 12.000  30.000  30.000  20.000  14.990  14.990  14.990
# 1995-12-31 15.000 14.990  13.000  12.000  12.000  12.000  11.990   1.074
#
# ...

# %%
import pandas as pd
i = '2011.csv'

# %%
 df= pd.read_csv('data_lake/raw/{}'.format(i))

# %%
df
# Out:
#      Unnamed: 0       Fecha          0          1          2          3  \
# 0             0  2011-01-01  88.106093  86.106093  65.106093  65.106093
# 1             1  2011-01-02  36.224485  36.224485  36.223485  36.223485
# 2             2  2011-01-03  58.104362  58.104362  58.104362  58.104362
# 3             3  2011-01-04  49.727173  49.727173  49.727173  49.727173
# 4             4  2011-01-05  34.337129  34.337129  34.337129  34.337129
# ..          ...         ...        ...        ...        ...        ...
# 364         364  2011-12-31  39.665407  39.665407  39.664407  39.665407
# 365         365         NaN        NaN        NaN        NaN        NaN
# 366         366         NaN        NaN        NaN        NaN        NaN
# 367         367         NaN        NaN        NaN        NaN        NaN
# 368         368         NaN        NaN        NaN        NaN        NaN
#
#              4          5          6          7  ...         14         15  \
# ...

# %%
df_melt = pd.melt(df, id_vars=['Fecha'], value_vars=df.columns[2:], var_name='hora', value_name='precio')
df_melt
# Out:
#            Fecha hora     precio
# 0     2011-01-01    0  88.106093
# 1     2011-01-02    0  36.224485
# 2     2011-01-03    0  58.104362
# 3     2011-01-04    0  49.727173
# 4     2011-01-05    0  34.337129
# ...          ...  ...        ...
# 8851  2011-12-31   23  51.789407
# 8852         NaN   23        NaN
# 8853         NaN   23        NaN
# 8854         NaN   23        NaN
# 8855         NaN   23        NaN
#
# [8856 rows x 3 columns]

# %%
df_melt.groupby('hora').count()
# Out:
#       Fecha  precio
# hora
# 0       365     365
# 1       365     365
# 10      365     365
# 11      365     365
# 12      365     365
# 13      365     365
# 14      365     365
# 15      365     365
# 16      365     365
# 17      365     365
# 18      365     365
# 19      365     365
# 2       365     365
# 20      365     365
# 21      365     365
# 22      365     365
# 23      365     365
# 3       365     365
# 4       365     365
# 5       365     365
# 6       365     365
# 7       365     365
# 8       365     365
# 9       365     365

# %%
df_fin = pd.DataFrame(columns=['Fecha', 'hora', 'precio'])
for i in range(2017, 2022):
    file_ = 'data_lake/raw/' + str(i) + '.csv'
    df_ini = pd.read_csv(file_)
    df_melt = pd.melt(df_ini, id_vars=['Fecha'], value_vars=df.columns[2:], var_name='hora', value_name='precio')
    df_fin = pd.concat([df_fin,df_melt], axis=0)

# %%
df_fin
# Out:
#            Fecha hora      precio
# 0     2017-01-01    0   88.086212
# 1     2017-01-02    0   69.268993
# 2     2017-01-03    0   69.472946
# 3     2017-01-04    0   61.376720
# 4     2017-01-05    0   65.442361
# ...          ...  ...         ...
# 2875  2021-04-26   23  173.890000
# 2876  2021-04-27   23  172.520000
# 2877  2021-04-28   23  147.250000
# 2878  2021-04-29   23  168.120000
# 2879  2021-04-30   23  125.420000
#
# [37944 rows x 3 columns]

# %%
df_fin.groupby('hora').count()
# Out:
#       Fecha  precio
# hora
# 0      1581    1581
# 1      1581    1581
# 10     1581    1581
# 11     1581    1581
# 12     1581    1581
# 13     1581    1581
# 14     1581    1581
# 15     1581    1581
# 16     1581    1581
# 17     1581    1581
# 18     1581    1581
# 19     1581    1581
# 2      1581    1581
# 20     1581    1581
# 21     1581    1581
# 22     1581    1581
# 23     1581    1581
# 3      1581    1581
# 4      1581    1581
# 5      1581    1581
# 6      1581    1581
# 7      1581    1581
# 8      1581    1581
# 9      1581    1581

# %%
df = pd.read_csv('data_lake/cleansed/precios-horarios.csv')

# %%
df_prom = df.groupby(['fecha']).mean().reset_index()

# %%
df
# Out:
#              fecha  hora     precio
# 0       1997-01-01     0   36.72627
# 1       1997-01-02     0   15.22627
# 2       1997-01-03     0   20.22627
# 3       1997-01-04     0   13.16627
# 4       1997-01-05     0   12.94527
# ...            ...   ...        ...
# 214963  2021-04-26    23  173.89000
# 214964  2021-04-27    23  172.52000
# 214965  2021-04-28    23  147.25000
# 214966  2021-04-29    23  168.12000
# 214967  2021-04-30    23  125.42000
#
# [214968 rows x 3 columns]

# %%
df['fecha'] =  df[['fecha']].apply(pd.to_datetime)
df['fecha'] = df['fecha'].dt.to_period('M').dt.to_timestamp()
df
# Out:
#             fecha  hora     precio
# 0      1997-01-01     0   36.72627
# 1      1997-01-01     0   15.22627
# 2      1997-01-01     0   20.22627
# 3      1997-01-01     0   13.16627
# 4      1997-01-01     0   12.94527
# ...           ...   ...        ...
# 214963 2021-04-01    23  173.89000
# 214964 2021-04-01    23  172.52000
# 214965 2021-04-01    23  147.25000
# 214966 2021-04-01    23  168.12000
# 214967 2021-04-01    23  125.42000
#
# [214968 rows x 3 columns]

# %%
df_month = df.groupby(['fecha']).mean().reset_index()
df_month
# Out:
#          fecha  hora      precio
# 0   1997-01-01  11.5   21.623433
# 1   1997-02-01  11.5   26.916226
# 2   1997-03-01  11.5   25.705822
# 3   1997-04-01  11.5   25.252256
# 4   1997-05-01  11.5   35.462962
# ..         ...   ...         ...
# 287 2020-12-01  11.5  163.230121
# 288 2021-01-01  11.5  181.475605
# 289 2021-02-01  11.5  270.126384
# 290 2021-03-01  11.5  165.896895
# 291 2021-04-01  11.5  162.536000
#
# [292 rows x 3 columns]

# %%
df['fecha'] = df['fecha'].dt.to_period('Y').dt.to_timestamp()
df_year = df.groupby(['fecha']).mean().reset_index()
df_year
# Out:
#         fecha  hora      precio
# 0  1997-01-01  11.5   64.795103
# 1  1998-01-01  11.5   49.993482
# 2  1999-01-01  11.5   28.252023
# 3  2000-01-01  11.5   44.737688
# 4  2001-01-01  11.5   52.470807
# 5  2002-01-01  11.5   48.727755
# 6  2003-01-01  11.5   66.725570
# 7  2004-01-01  11.5   64.170137
# 8  2005-01-01  11.5   74.359296
# 9  2006-01-01  11.5   73.793733
# 10 2007-01-01  11.5   83.827975
# 11 2008-01-01  11.5   87.875340
# 12 2009-01-01  11.5  141.159135
# 13 2010-01-01  11.5  128.722205
# 14 2011-01-01  11.5   75.013184
# 15 2012-01-01  11.5  116.000389
# 16 2013-01-01  11.5  177.378993
# 17 2014-01-01  11.5  224.983846
# 18 2015-01-01  11.5  378.107371
# 19 2016-01-01  11.5  299.802180
# 20 2017-01-01  11.5  106.104809
# 21 2018-01-01  11.5  116.248821
# 22 2019-01-01  11.5  228.308441
# 23 2020-01-01  11.5  251.102195
# 24 2021-01-01  11.5  193.401385

# %%
df
# Out:
#             fecha  hora     precio
# 0      1997-01-01     0   36.72627
# 1      1997-01-01     0   15.22627
# 2      1997-01-01     0   20.22627
# 3      1997-01-01     0   13.16627
# 4      1997-01-01     0   12.94527
# ...           ...   ...        ...
# 214963 2021-01-01    23  173.89000
# 214964 2021-01-01    23  172.52000
# 214965 2021-01-01    23  147.25000
# 214966 2021-01-01    23  168.12000
# 214967 2021-01-01    23  125.42000
#
# [214968 rows x 3 columns]

# %%
df_m = pd.read_csv('data_lake/business/precios-diarios.csv', index_col = 0)

# %%
df_m
# Out:
#             hora      precio
# fecha
# 1997-01-01  11.5   24.194228
# 1997-01-02  11.5   23.417937
# 1997-01-03  11.5   21.348312
# 1997-01-04  11.5   16.795228
# 1997-01-05  11.5   15.358270
# ...          ...         ...
# 2021-04-26  11.5  188.325833
# 2021-04-27  11.5  181.770000
# 2021-04-28  11.5  175.874167
# 2021-04-29  11.5  165.203333
# 2021-04-30  11.5  144.489167
#
# [8886 rows x 2 columns]

# %%
df_m['fecha'] =  df_m[['fecha']].apply(pd.to_datetime)
plot = df_m.plot.line()

# %%
df_m['precio'].plot(figsize=(15,5))
# Out:
# <AxesSubplot:xlabel='fecha'>

# %%
ax =df_m['precio'].plot(figsize=(15,5), kind='line', grid=True, x_compat=False)

# %%
type(ax)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
fig = ax.get_figure()
fig.savefig('data_lake/business/reports/figures/daily_prices.png')

# %%
df_mo = pd.read_csv('data_lake/business/precios-mensuales.csv', index_col=0)

# %%
ax =df_mo['precio'].plot(figsize=(15,5), kind='line', grid=True, x_compat=False)

# %% [markdown]
# # Pronostico

# %%
import pandas as pd
df = pd.read_csv('data_lake/business/precios-diarios.csv')

# %%
df
# Out:
#           fecha  hora      precio
# 0    1997-01-01  11.5   24.194228
# 1    1997-01-02  11.5   23.417937
# 2    1997-01-03  11.5   21.348312
# 3    1997-01-04  11.5   16.795228
# 4    1997-01-05  11.5   15.358270
# ...         ...   ...         ...
# 8881 2021-04-26  11.5  188.325833
# 8882 2021-04-27  11.5  181.770000
# 8883 2021-04-28  11.5  175.874167
# 8884 2021-04-29  11.5  165.203333
# 8885 2021-04-30  11.5  144.489167
#
# [8886 rows x 3 columns]

# %%
df['fecha'] = pd.to_datetime(df['fecha'], format='%Y-%m-%d')
df['weekday'] = df.fecha.dt.weekday 
df
# Out:
#           fecha  hora      precio  weekday
# 0    1997-01-01  11.5   24.194228        2
# 1    1997-01-02  11.5   23.417937        3
# 2    1997-01-03  11.5   21.348312        4
# 3    1997-01-04  11.5   16.795228        5
# 4    1997-01-05  11.5   15.358270        6
# ...         ...   ...         ...      ...
# 8881 2021-04-26  11.5  188.325833        0
# 8882 2021-04-27  11.5  181.770000        1
# 8883 2021-04-28  11.5  175.874167        2
# 8884 2021-04-29  11.5  165.203333        3
# 8885 2021-04-30  11.5  144.489167        4
#
# [8886 rows x 4 columns]

# %%
import seaborn as sns

sns.pairplot(df)

# %%
Se observa que el precio tiee distribución uniforme todos los días

# %%
from sklearn.model_selection import train_test_split
import numpy as np

X = np.array(df['weekday']).reshape(-1,1)
y = np.array(df['precio']).reshape(-1,1)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=33
)
print (X.shape)
print (y.shape)
# Out:
# (8886, 1)
# (8886, 1)

# %%
type(y_train[0])
# Out:
# numpy.float64

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error

# Crea el modelo
regr = linear_model.LinearRegression()
regr.fit(X_train, y_train)
# Imprime los coeficientes
print("Coeficientes: ", regr.coef_)

# Imprime el intercepto
print("\nIntercepto: ", regr.intercept_)
# Out:
# Coeficientes:  [[-1.04851286]]
#
# Intercepto:  [126.93111349]

# %%
y_pred = regr.predict(X_test)
print("R^2: {:6.4f}".format(regr.score(X_test, y_test)))
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error: {:6.4f}".format(rmse))
# Out:
# R^2: -0.0007
# Root Mean Squared Error: 144.6255

# %% [markdown]
# ## Analisis pronostico

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression

day = df['weekday']
precio = df['precio']

plt.figure(figsize=(7, 7))
plt.scatter(day, precio, color="tab:blue", alpha=0.8, edgecolors="white")
plt.gca().spines["left"].set_color("gray")
plt.gca().spines["bottom"].set_color("gray")
plt.gca().spines["top"].set_visible(False)
plt.gca().spines["right"].set_visible(False)
plt.plot()
# Out:
# []

# %%
line_X = np.linspace(day.min(), day.max())[:, np.newaxis]
y_pred = regr.predict(line_X)

plt.figure(figsize=(7, 7))

plt.scatter(day, precio, color="tab:blue", alpha=0.8, edgecolors="white")
plt.plot(line_X, y_pred, "k", linewidth=2)

plt.gca().spines["left"].set_color("gray")
plt.gca().spines["bottom"].set_color("gray")
plt.gca().spines["top"].set_visible(False)
plt.gca().spines["right"].set_visible(False)

plt.show()

# %%
plt.figure(figsize=(7, 7))
plt.scatter(X_test, y_test, color="tab:blue", alpha=0.8, edgecolors="white")
plt.gca().spines["left"].set_color("gray")
plt.gca().spines["bottom"].set_color("gray")
plt.gca().spines["top"].set_visible(False)
plt.gca().spines["right"].set_visible(False)
plt.plot()
# Out:
# []

# %%
regr.fit(X_train, y_train)
y_pred = regr.predict(X_test)
plt.figure(figsize=(7, 7))

plt.scatter(X_test, y_test, color="tab:gray", alpha=0.8, edgecolors="white")
plt.scatter(X_test, y_pred, color="tab:green", alpha=0.8, edgecolors="white")
plt.gca().spines["left"].set_color("gray")
plt.gca().spines["bottom"].set_color("gray")
plt.gca().spines["top"].set_visible(False)
plt.gca().spines["right"].set_visible(False)
plt.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_10494/4020867069.py in <module>
# ----> 1 regr.fit(X_train, y_train)
#       2 y_pred = regr.predict(X_test)
#       3 plt.figure(figsize=(7, 7))
#       4
#       5 plt.scatter(X_test, y_test, color="tab:gray", alpha=0.8, edgecolors="white")
#
# NameError: name 'regr' is not defined

# %%
import pandas as pd
import pickle
import numpy as np
from sklearn.model_selection import train_test_split

df = pd.read_csv('data_lake/business/features/precios_diarios.csv')
df['fecha'] = pd.to_datetime(df['fecha'], format='%Y-%m-%d')
df['weekday'] = pd.to_numeric(df['weekday'])

X = np.array(df['weekday']).reshape(-1, 1)
y = np.array(df['precio']).reshape(-1, 1)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=33
)

with open('src/models/precios-diarios.pkl', 'rb') as f:
    estimator = pickle.load(f)

# %%
pred_precio = estimator.predict(X)
pred_precio
# Out:
# array([[124.83408778],
#        [123.78557492],
#        [122.73706206],
#        ...,
#        [124.83408778],
#        [123.78557492],
#        [122.73706206]])

# %%
df
# Out:
#           fecha  hora      precio  weekday
# 0    1997-01-01  11.5   24.194228        2
# 1    1997-01-02  11.5   23.417937        3
# 2    1997-01-03  11.5   21.348312        4
# 3    1997-01-04  11.5   16.795228        5
# 4    1997-01-05  11.5   15.358270        6
# ...         ...   ...         ...      ...
# 8881 2021-04-26  11.5  188.325833        0
# 8882 2021-04-27  11.5  181.770000        1
# 8883 2021-04-28  11.5  175.874167        2
# 8884 2021-04-29  11.5  165.203333        3
# 8885 2021-04-30  11.5  144.489167        4
#
# [8886 rows x 4 columns]

# %%
df['pred_precio']=pred_precio
df[['fecha','precio','pred_precio']]
# Out:
#           fecha      precio  pred_precio
# 0    1997-01-01   24.194228   124.834088
# 1    1997-01-02   23.417937   123.785575
# 2    1997-01-03   21.348312   122.737062
# 3    1997-01-04   16.795228   121.688549
# 4    1997-01-05   15.358270   120.640036
# ...         ...         ...          ...
# 8881 2021-04-26  188.325833   126.931113
# 8882 2021-04-27  181.770000   125.882601
# 8883 2021-04-28  175.874167   124.834088
# 8884 2021-04-29  165.203333   123.785575
# 8885 2021-04-30  144.489167   122.737062
#
# [8886 rows x 3 columns]

# %%
ans = df[['fecha', 'precio', 'pred_precio']]
ans
# Out:
#           fecha      precio  pred_precio
# 0    1997-01-01   24.194228   124.834088
# 1    1997-01-02   23.417937   123.785575
# 2    1997-01-03   21.348312   122.737062
# 3    1997-01-04   16.795228   121.688549
# 4    1997-01-05   15.358270   120.640036
# ...         ...         ...          ...
# 8881 2021-04-26  188.325833   126.931113
# 8882 2021-04-27  181.770000   125.882601
# 8883 2021-04-28  175.874167   124.834088
# 8884 2021-04-29  165.203333   123.785575
# 8885 2021-04-30  144.489167   122.737062
#
# [8886 rows x 3 columns]

# %%
import pandas as pd
df_test = pd.read_csv('../data_lake/business/precios-diarios.csv')
df_test2 = pd.read_csv('../data_lake/business/precios-mensuales.csv')
df_test3 = pd.read_csv('../data_lake/cleansed/precios-horarios.csv')

# %%
assert1 = df_test.shape
assert2 = df_test2.shape
assert3 = df_test3.shape

# %%
assert3
# Out:
# (214968, 3)

# %%
expect1 = (8886,3)
expect2 = (192,3)
expect3 = (214968,3)

# %%
assert1
# Out:
# (8886, 3)

# %%
assert expect1 == assert1 is True
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipykernel_18494/394169003.py in <module>
# ----> 1 assert expect1 == assert1 is False
#
# AssertionError:

# %%
a = (expect1 == assert1)

# %%
a
# Out:
# True
